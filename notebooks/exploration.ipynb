# %% [markdown]
# # Exploration
#
# Use this notebook to try cleaning, sentiment, and quick plots. Run the CLI pipeline from the repo root first (see README Quick start), then load CSVs from `../data/processed/`.

# %%
from pathlib import Path
import pandas as pd

root = Path("..").resolve()
sent = root / "data" / "processed" / "sentiment_results.csv"
if sent.exists():
    display(pd.read_csv(sent).head())
else:
    print("Run the pipeline first to generate", sent)
